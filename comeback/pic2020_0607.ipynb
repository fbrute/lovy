# %%
import pandas as pd

# %%
filenames = [name + '.csv' for name in ['pic2020_0607_guadeloupe']]
filenames
# Out:
# ['pic2020_0607_guadeloupe.csv']

# %% [markdown]
# ## Choose station

# %%
filename = filenames[0]

# %% [markdown]
# ## Choose station

# %%
station_df = pd.read_csv(filename, sep=';')
station_df['id'] = station_df.index
print(len(station_df.index))
station_df.head()
# Out:
# 25
#    dd  mm  yyyy  AOD_1640nm  AOD_1020nm  AOD_870nm  AOD_865nm  AOD_779nm  \
# 0   1   6  2020    0.074632    0.087599   0.092277     -999.0     -999.0
# 1   2   6  2020    0.057015    0.066145   0.070452     -999.0     -999.0
# 2   3   6  2020    0.076471    0.085287   0.086994     -999.0     -999.0
# 3   7   6  2020    0.074134    0.077534   0.082270     -999.0     -999.0
# 4   8   6  2020    0.031206    0.037082   0.042353     -999.0     -999.0
#
#    AOD_675nm  AOD_667nm  ...  N[500-870_Angstrom_Exponent]  \
# 0   0.110516     -999.0  ...                            31
# 1   0.091177     -999.0  ...                            14
# 2   0.098199     -999.0  ...                            10
# 3   0.101491     -999.0  ...                            13
# 4   0.063124     -999.0  ...                            33
#
#    N[340-440_Angstrom_Exponent]  N[440-675_Angstrom_Exponent[Polar]]  \
# 0                            31                                    0
# ...

# %%
lambdas = ['440', '1020']

# %% [markdown]
# ## Choose lambda

# %%
lambda_val = lambdas[0]

# %% [markdown]
# ## Select a minimum of 2 observations (nobs => N[{lambda_val}nm]  with pic2020_0607)

# %%
#station_df = station_df[station_df['nobs'] >= 2]
station_df = station_df[station_df[f"N[AOD_{lambda_val}nm]"] >= 2]
print(len(station_df.index))
station_df.head()
# Out:
# 25
#    dd  mm  yyyy  AOD_1640nm  AOD_1020nm  AOD_870nm  AOD_865nm  AOD_779nm  \
# 0   1   6  2020    0.074632    0.087599   0.092277     -999.0     -999.0
# 1   2   6  2020    0.057015    0.066145   0.070452     -999.0     -999.0
# 2   3   6  2020    0.076471    0.085287   0.086994     -999.0     -999.0
# 3   7   6  2020    0.074134    0.077534   0.082270     -999.0     -999.0
# 4   8   6  2020    0.031206    0.037082   0.042353     -999.0     -999.0
#
#    AOD_675nm  AOD_667nm  ...  N[500-870_Angstrom_Exponent]  \
# 0   0.110516     -999.0  ...                            31
# 1   0.091177     -999.0  ...                            14
# 2   0.098199     -999.0  ...                            10
# 3   0.101491     -999.0  ...                            13
# 4   0.063124     -999.0  ...                            33
#
#    N[340-440_Angstrom_Exponent]  N[440-675_Angstrom_Exponent[Polar]]  \
# 0                            31                                    0
# ...

# %% [markdown]
# ## Select columns : year, month, days, id and nobs

# %%
ymd_df = station_df.filter(regex=f"yyyy|mm|dd|id|N[AOD_{lambda_val}nm]", axis = 1)
ymd_df.head()
# Out:
#    dd  mm  yyyy  id
# 0   1   6  2020   0
# 1   2   6  2020   1
# 2   3   6  2020   2
# 3   7   6  2020   3
# 4   8   6  2020   4

# %%
aod_nobs_df = station_df.filter(regex=f"id|N[AOD_{lambda_val}nm]", axis = 1)
result_df = ymd_df.merge(aod_nobs_df, on='id', how='inner')
result_df.head()
# Out:
#    dd  mm  yyyy  id
# 0   1   6  2020   0
# 1   2   6  2020   1
# 2   3   6  2020   2
# 3   7   6  2020   3
# 4   8   6  2020   4

# %%
lambdas = ['440', '1020']

# %% [markdown]
# ## Choose lambda

# %%
lambda_val = lambdas[0]

# %% [markdown]
# ## Add a column to result_df

# %%
def add_columns(regexp, source_df, result_df):
    source2_df = source_df.copy()
    result2_df = result_df.copy()
    columns_df = source2_df.filter(regex=regexp, axis = 1)
    result_df = columns_df.merge(result2_df, on='id', how='inner')

# %% [markdown]
# ## AOD lambda_val

# %%
lambda_df_AOT_avg_std = station_df.filter(regex=f"^AOD_{lambda_val}|id", axis = 1)
result_df = ymd_df.merge(lambda_df_AOT_avg_std, on='id', how='inner')
result_df.head()
# Out:
#    dd  mm  yyyy  id  AOD_440nm
# 0   1   6  2020   0   0.117902
# 1   2   6  2020   1   0.097885
# 2   3   6  2020   2   0.109231
# 3   7   6  2020   3   0.111557
# 4   8   6  2020   4   0.077671

# %%
lambda_df = station_df.filter(regex=f"^AOD_{lambda_val}_med|id", axis = 1)
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()
# Out:
#    dd  mm  yyyy  id  AOD_440nm
# 0   1   6  2020   0   0.117902
# 1   2   6  2020   1   0.097885
# 2   3   6  2020   2   0.109231
# 3   7   6  2020   3   0.111557
# 4   8   6  2020   4   0.077671

# %% [markdown]
# ## 440-870_Angstrom_Exponent

# %%
lambda_df = station_df.filter(regex=f"^440-870_Angstrom_Exponent|id", axis = 1)
print(lambda_df.head())
#result_df = result_df.merge(lambda_df, on='id', how='inner')
#result_df.head()
# Out:
#    440-870_Angstrom_Exponent  id
# 0                   0.321680   0
# 1                   0.423971   1
# 2                   0.328898   2
# 3                   0.424079   3
# 4                   0.831222   4

# %%
lambda_df = station_df.filter(regex=f"870-440AngstromParam,\[AOTExt\]-Total_med|id", axis = 1)
#print(lambda_df.head())
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()
# Out:
#    dd  mm  yyyy  nobs  id AOT_1020_avg AOT_1020_std AOT_1020_med  \
# 0  20   6  1998     2   0     0,378359  0,000850499     0,378359
# 1  22   4  1999     2  11     0,062176     0,008567     0,062176
# 2  29   4  1999     2  13    0,0861475    0,0040385    0,0861475
# 3   6   5  1999     2  15    0,0734765    0,0063095    0,0734765
# 4   7   5  1999     2  16     0,170561    0,0133005      0,17056
#
#   AOTExt1020-T_avg AOTExt1020-T_std  ... ASYM1020-T_med ASYM1020-C_avg  \
# 0          0,38135          0,00125  ...       0,768597        0,77871
# 1           0,0628           0,0092  ...        0,76347       0,794523
# 2          0,08705          0,00385  ...       0,757179       0,788928
# 3          0,07575          0,00705  ...       0,740154        0,76682
# 4          0,16985          0,01295  ...       0,717893       0,740638
#
#   ASYM1020-C_std ASYM1020-C_med ASYM1020-F_avg ASYM1020-F_std ASYM1020-F_med  \
# ...

# %% [markdown]
# ## Inflection_Point

# %%
lambda_df = station_df.filter(regex=f"Inflection_Point\[um\]_[avg$|std$]|id", axis = 1)
#print(lambda_df.head())
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()
# Out:
#    dd  mm  yyyy  nobs  id AOT_1020_avg AOT_1020_std AOT_1020_med  \
# 0  20   6  1998     2   0     0,378359  0,000850499     0,378359
# 1  22   4  1999     2  11     0,062176     0,008567     0,062176
# 2  29   4  1999     2  13    0,0861475    0,0040385    0,0861475
# 3   6   5  1999     2  15    0,0734765    0,0063095    0,0734765
# 4   7   5  1999     2  16     0,170561    0,0133005      0,17056
#
#   AOTExt1020-T_avg AOTExt1020-T_std  ... ASYM1020-C_std ASYM1020-C_med  \
# 0          0,38135          0,00125  ...       0,005954        0,77871
# 1           0,0628           0,0092  ...     0,00600252       0,794523
# 2          0,08705          0,00385  ...     0,00434902       0,788928
# 3          0,07575          0,00705  ...     0,00421301        0,76682
# 4          0,16985          0,01295  ...      0,0192565       0,740638
#
#   ASYM1020-F_avg ASYM1020-F_std ASYM1020-F_med  \
# 0       0,577295       0,021953       0,577295
# 1       0,459565      0,0211155       0,459565
# ...

# %%
lambda_df = station_df.filter(regex=f"Inflection_Point\[um\]_med|id", axis = 1)
#print(lambda_df.head())
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()
# Out:
#    dd  mm  yyyy  nobs  id AOT_1020_avg AOT_1020_std AOT_1020_med  \
# 0  20   6  1998     2   0     0,378359  0,000850499     0,378359
# 1  22   4  1999     2  11     0,062176     0,008567     0,062176
# 2  29   4  1999     2  13    0,0861475    0,0040385    0,0861475
# 3   6   5  1999     2  15    0,0734765    0,0063095    0,0734765
# 4   7   5  1999     2  16     0,170561    0,0133005      0,17056
#
#   AOTExt1020-T_avg AOTExt1020-T_std  ... ASYM1020-C_med ASYM1020-F_avg  \
# 0          0,38135          0,00125  ...        0,77871       0,577295
# 1           0,0628           0,0092  ...       0,794523       0,459565
# 2          0,08705          0,00385  ...       0,788928       0,503852
# 3          0,07575          0,00705  ...        0,76682       0,544576
# 4          0,16985          0,01295  ...       0,740638       0,550445
#
#   ASYM1020-F_std ASYM1020-F_med 870-440AngstromParam,[AOTExt]-Total_avg  \
# ...

# %% [markdown]
# ## HE *

# %%
values = ["0,500000","0,065604","0,086077","0,112939","0,148184","0,194429","0,255105","0,334716",
          "0,439173","0,576227","0,756052","0,991996","1,301571","1,707757","2,240702",
          "2,939966","3,857452","5,061260","6,640745","8,713145","11,432287","15,000000"]

# %%
for value in values:
    lambda_df = station_df.filter(regex=f"{value}_[avg$|std$]|id", axis = 1)
    result_df = result_df.merge(lambda_df, on='id', how='inner')
    lambda_df = station_df.filter(regex=f"{value}_med|id", axis = 1)
    result_df = result_df.merge(lambda_df, on='id', how='inner')

# %%
result_df = result_df.drop(['id'], axis = 1)

# %%
result_df.to_csv(f"comeback_{lambda_val}_{filename}", index=False)
