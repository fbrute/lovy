# %%
import pandas as pd

# %%
filenames = [name + '.csv' for name in ['ragged_point', 'san_juan','barbados','guadeloupe']]
filenames
# Out:
# ['ragged_point.csv', 'san_juan.csv', 'barbados.csv', 'guadeloupe.csv']

# %% [markdown]
# ## Choose station

# %%
filename = filenames[3]

# %% [markdown]
# ## Choose station

# %%
station_df = pd.read_csv(filename, sep=';')
station_df['id'] = station_df.index
print(len(station_df.index))
station_df.head()
# Out:
# 441
#    dd  mm  yyyy  nobs AOT_1020_avg  AOT_1020_nobs AOT_1020_std AOT_1020_min  \
# 0  20   6  1998     2     0,378359              2  0,000850499     0,377509
# 1  30   6  1998     1     0,419631              1            0     0,419631
# 2   1   7  1998     1     0,254896              1            0     0,254896
# 3   6   7  1998     1     0,061421              1            0     0,061421
# 4  11   7  1998     1     0,039628              1            0     0,039628
#
#   AOT_1020_max AOT_1020_per5  ... albedo-1020_per95  \
# 0      0,37921      0,377594  ...          0,354899
# 1     0,419631           NaN  ...               NaN
# 2     0,254896           NaN  ...               NaN
# 3     0,061421           NaN  ...               NaN
# 4     0,039628           NaN  ...               NaN
#
#   average_solar_zenith_angle_for_flux_calculation_avg  \
# 0                                            72,1125
# 1                                             76,245
# 2                                             60,794
# 3                                            76,2684
# 4                                            69,6106
#
#   average_solar_zenith_angle_for_flux_calculation_nobs  \
# 0                                                  2
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    average_solar_zenith_angle_for_flux_calculation_std  \
# 0                                            2,48961
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#   average_solar_zenith_angle_for_flux_calculation_min  \
# 0                                            69,6229
# 1                                             76,245
# 2                                             60,794
# 3                                            76,2684
# 4                                            69,6106
#
#   average_solar_zenith_angle_for_flux_calculation_max  \
# 0                                            74,6021
# 1                                             76,245
# 2                                             60,794
# 3                                            76,2684
# 4                                            69,6106
#
#   average_solar_zenith_angle_for_flux_calculation_per5  \
# 0                                            69,8719
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   average_solar_zenith_angle_for_flux_calculation_med  \
# 0                                            72,1125
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   average_solar_zenith_angle_for_flux_calculation_per95 id
# 0                                            74,3531     0
# 1                                                NaN     1
# 2                                                NaN     2
# 3                                                NaN     3
# 4                                                NaN     4
#
# [5 rows x 901 columns]

# %% [markdown]
# ## Select a minimum of 2 observations

# %%
station_df = station_df[station_df['nobs'] >= 2]
print(len(station_df.index))
station_df.head()
# Out:
# 206
#     dd  mm  yyyy  nobs AOT_1020_avg  AOT_1020_nobs AOT_1020_std AOT_1020_min  \
# 0   20   6  1998     2     0,378359              2  0,000850499     0,377509
# 11  22   4  1999     2     0,062176              2     0,008567     0,053609
# 13  29   4  1999     2    0,0861475              2    0,0040385     0,082109
# 15   6   5  1999     2    0,0734765              2    0,0063095     0,067167
# 16   7   5  1999     2     0,170561              2    0,0133005      0,15726
#
#    AOT_1020_max AOT_1020_per5  ... albedo-1020_per95  \
# 0       0,37921      0,377594  ...          0,354899
# 11     0,070743     0,0544657  ...           0,27696
# 13     0,090186     0,0825128  ...          0,354701
# 15     0,079786      0,067798  ...          0,325118
# 16     0,183861       0,15859  ...          0,283085
#
#    average_solar_zenith_angle_for_flux_calculation_avg  \
# 0                                             72,1125
# 11                                            57,8068
# 13                                            65,5838
# 15                                            63,1368
# 16                                            57,9077
#
#    average_solar_zenith_angle_for_flux_calculation_nobs  \
# 0                                                   2
# 11                                                  2
# 13                                                  2
# 15                                                  2
# 16                                                  2
#
#     average_solar_zenith_angle_for_flux_calculation_std  \
# 0                                             2,48961
# 11                                            3,00318
# 13                                            10,7056
# 15                                            8,23161
# 16                                            3,00542
#
#    average_solar_zenith_angle_for_flux_calculation_min  \
# 0                                             69,6229
# 11                                            54,8036
# 13                                            54,8782
# 15                                            54,9052
# 16                                            54,9023
#
#    average_solar_zenith_angle_for_flux_calculation_max  \
# 0                                             74,6021
# 11                                            60,8099
# 13                                            76,2893
# 15                                            71,3684
# 16                                            60,9132
#
#    average_solar_zenith_angle_for_flux_calculation_per5  \
# 0                                             69,8719
# 11                                            55,1039
# 13                                            55,9488
# 15                                            55,7284
# 16                                            55,2028
#
#    average_solar_zenith_angle_for_flux_calculation_med  \
# 0                                             72,1125
# 11                                            57,8068
# 13                                            65,5837
# 15                                            63,1368
# 16                                            57,9077
#
#    average_solar_zenith_angle_for_flux_calculation_per95  id
# 0                                             74,3531      0
# 11                                            60,5096     11
# 13                                            75,2187     13
# 15                                            70,5452     15
# 16                                            60,6127     16
#
# [5 rows x 901 columns]

# %% [markdown]
# ## Select columns : year, month, days, id and nobs

# %%
ymd_df = station_df.filter(regex='yyyy|mm|dd|id|^nobs$', axis = 1)
ymd_df.head()
# Out:
#     dd  mm  yyyy  nobs  id
# 0   20   6  1998     2   0
# 11  22   4  1999     2  11
# 13  29   4  1999     2  13
# 15   6   5  1999     2  15
# 16   7   5  1999     2  16

# %%
lambdas = ['440', '1020']

# %% [markdown]
# ## Choose lambda

# %%
lambda_val = lambdas[1]

# %% [markdown]
# ## Add a column to result_df

# %%
def add_columns(regexp, source_df, result_df):
    source2_df = source_df.copy()
    result2_df = result_df.copy()
    columns_df = source2_df.filter(regex=regexp, axis = 1)
    result_df = columns_df.merge(result2_df, on='id', how='inner')

# %% [markdown]
# ## AOT lambda_val

# %%
lambda_df_AOT_avg_std = station_df.filter(regex=f"AOT_{lambda_val}_[avg|std]|id", axis = 1)
result_df = ymd_df.merge(lambda_df_AOT_avg_std, on='id', how='inner')
result_df.head()
# Out:
#    dd  mm  yyyy  nobs  id AOT_1020_avg AOT_1020_std
# 0  20   6  1998     2   0     0,378359  0,000850499
# 1  22   4  1999     2  11     0,062176     0,008567
# 2  29   4  1999     2  13    0,0861475    0,0040385
# 3   6   5  1999     2  15    0,0734765    0,0063095
# 4   7   5  1999     2  16     0,170561    0,0133005

# %%
lambda_df = station_df.filter(regex=f"AOT_{lambda_val}_med|id", axis = 1)
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()
# Out:
#    dd  mm  yyyy  nobs  id AOT_1020_avg AOT_1020_std AOT_1020_med
# 0  20   6  1998     2   0     0,378359  0,000850499     0,378359
# 1  22   4  1999     2  11     0,062176     0,008567     0,062176
# 2  29   4  1999     2  13    0,0861475    0,0040385    0,0861475
# 3   6   5  1999     2  15    0,0734765    0,0063095    0,0734765
# 4   7   5  1999     2  16     0,170561    0,0133005      0,17056

# %% [markdown]
# ## AOTExt(lambda_val)_T

# %%
lambda_df = station_df.filter(regex=f"AOTExt{lambda_val}-T_[avg$|std$]|id", axis = 1)
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()
# Out:
#    dd  mm  yyyy  nobs  id AOT_1020_avg AOT_1020_std AOT_1020_med  \
# 0  20   6  1998     2   0     0,378359  0,000850499     0,378359
# 1  22   4  1999     2  11     0,062176     0,008567     0,062176
# 2  29   4  1999     2  13    0,0861475    0,0040385    0,0861475
# 3   6   5  1999     2  15    0,0734765    0,0063095    0,0734765
# 4   7   5  1999     2  16     0,170561    0,0133005      0,17056
#
#   AOTExt1020-T_avg AOTExt1020-T_std
# 0          0,38135          0,00125
# 1           0,0628           0,0092
# 2          0,08705          0,00385
# 3          0,07575          0,00705
# 4          0,16985          0,01295

# %%
lambda_df = station_df.filter(regex=f"AOTExt{lambda_val}-T_med|id", axis = 1)
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()
# Out:
#    dd  mm  yyyy  nobs  id AOT_1020_avg AOT_1020_std AOT_1020_med  \
# 0  20   6  1998     2   0     0,378359  0,000850499     0,378359
# 1  22   4  1999     2  11     0,062176     0,008567     0,062176
# 2  29   4  1999     2  13    0,0861475    0,0040385    0,0861475
# 3   6   5  1999     2  15    0,0734765    0,0063095    0,0734765
# 4   7   5  1999     2  16     0,170561    0,0133005      0,17056
#
#   AOTExt1020-T_avg AOTExt1020-T_std AOTExt1020-T_med
# 0          0,38135          0,00125          0,38135
# 1           0,0628           0,0092           0,0628
# 2          0,08705          0,00385          0,08705
# 3          0,07575          0,00705          0,07575
# 4          0,16985          0,01295          0,16985

# %% [markdown]
# ## AOTExt(lambda_val)_C

# %%
lambda_df = station_df.filter(regex=f"AOTExt{lambda_val}-C_[avg$|std$]|id", axis = 1)
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()
# Out:
#    dd  mm  yyyy  nobs  id AOT_1020_avg AOT_1020_std AOT_1020_med  \
# 0  20   6  1998     2   0     0,378359  0,000850499     0,378359
# 1  22   4  1999     2  11     0,062176     0,008567     0,062176
# 2  29   4  1999     2  13    0,0861475    0,0040385    0,0861475
# 3   6   5  1999     2  15    0,0734765    0,0063095    0,0734765
# 4   7   5  1999     2  16     0,170561    0,0133005      0,17056
#
#   AOTExt1020-T_avg AOTExt1020-T_std AOTExt1020-T_med AOTExt1020-C_avg  \
# 0          0,38135          0,00125          0,38135           0,3617
# 1           0,0628           0,0092           0,0628           0,0567
# 2          0,08705          0,00385          0,08705           0,0773
# 3          0,07575          0,00705          0,07575          0,06645
# 4          0,16985          0,01295          0,16985          0,14985
#
#   AOTExt1020-C_std
# 0       0,00139999
# 1           0,0076
# 2           0,0033
# 3          0,00495
# 4          0,01355

# %%
lambda_df = station_df.filter(regex=f"AOTExt{lambda_val}-C_med|id", axis = 1)
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()
# Out:
#    dd  mm  yyyy  nobs  id AOT_1020_avg AOT_1020_std AOT_1020_med  \
# 0  20   6  1998     2   0     0,378359  0,000850499     0,378359
# 1  22   4  1999     2  11     0,062176     0,008567     0,062176
# 2  29   4  1999     2  13    0,0861475    0,0040385    0,0861475
# 3   6   5  1999     2  15    0,0734765    0,0063095    0,0734765
# 4   7   5  1999     2  16     0,170561    0,0133005      0,17056
#
#   AOTExt1020-T_avg AOTExt1020-T_std AOTExt1020-T_med AOTExt1020-C_avg  \
# 0          0,38135          0,00125          0,38135           0,3617
# 1           0,0628           0,0092           0,0628           0,0567
# 2          0,08705          0,00385          0,08705           0,0773
# 3          0,07575          0,00705          0,07575          0,06645
# 4          0,16985          0,01295          0,16985          0,14985
#
#   AOTExt1020-C_std AOTExt1020-C_med
# 0       0,00139999           0,3617
# 1           0,0076           0,0567
# 2           0,0033           0,0773
# 3          0,00495          0,06645
# 4          0,01355          0,14985

# %% [markdown]
# ## AOTExt(lambda_val)_F

# %%
lambda_df = station_df.filter(regex=f"AOTExt{lambda_val}-F_[avg$|std$]|id", axis = 1)
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()
# Out:
#    dd  mm  yyyy  nobs  id AOT_1020_avg AOT_1020_std AOT_1020_med  \
# 0  20   6  1998     2   0     0,378359  0,000850499     0,378359
# 1  22   4  1999     2  11     0,062176     0,008567     0,062176
# 2  29   4  1999     2  13    0,0861475    0,0040385    0,0861475
# 3   6   5  1999     2  15    0,0734765    0,0063095    0,0734765
# 4   7   5  1999     2  16     0,170561    0,0133005      0,17056
#
#   AOTExt1020-T_avg AOTExt1020-T_std AOTExt1020-T_med AOTExt1020-C_avg  \
# 0          0,38135          0,00125          0,38135           0,3617
# 1           0,0628           0,0092           0,0628           0,0567
# 2          0,08705          0,00385          0,08705           0,0773
# 3          0,07575          0,00705          0,07575          0,06645
# 4          0,16985          0,01295          0,16985          0,14985
#
#   AOTExt1020-C_std AOTExt1020-C_med AOTExt1020-F_avg AOTExt1020-F_std
# 0       0,00139999           0,3617          0,01965          0,00265
# 1           0,0076           0,0567           0,0061           0,0016
# 2           0,0033           0,0773           0,0098           0,0005
# 3          0,00495          0,06645           0,0093           0,0021
# 4          0,01355          0,14985             0,02           0,0006

# %%
lambda_df_AOTExt_F_med = station_df.filter(regex=f"AOTExt{lambda_val}-F_med", axis = 1)
print(len(lambda_df_AOTExt_F_med.index))
frames.append(lambda_df_AOTExt_F_med)
# Out:
# 206
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-2803580e0bc6> in <module>
#       1 lambda_df_AOTExt_F_med = station_df.filter(regex=f"AOTExt{lambda_val}-F_med", axis = 1)
#       2 print(len(lambda_df_AOTExt_F_med.index))
# ----> 3 frames.append(lambda_df_AOTExt_F_med)
#
# NameError: name 'frames' is not defined

# %% [markdown]
# ## AOTAbsp(lambda_val)_T

# %%
lambda_df = station_df.filter(regex=f"AOTAbsp{lambda_val}-T_[avg$|std$]|id", axis = 1)
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()

# %%
lambda_df = station_df.filter(regex=f"AOTAbsp{lambda_val}-T_med|id", axis = 1)
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()

# %% [markdown]
# ## SSA(lambda_val)_T

# %%
lambda_df = station_df.filter(regex=f"SSA{lambda_val}-T_[avg$|std$]|id", axis = 1)
#print(lambda_df.head())
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()

# %%
lambda_df = station_df.filter(regex=f"SSA{lambda_val}-T_med|id", axis = 1)
#print(lambda_df.head())
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()

# %%
lambda_df = station_df.filter(regex=f"AOTAbsp{lambda_val}-C_[avg$|std$]|id", axis = 1)
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()

# %% [markdown]
# ## REFR((lambda_val))_F

# %%
lambda_df = station_df.filter(regex=f"REFR\({lambda_val}\)_[avg$|std$]|id", axis = 1)
#print(lambda_df.head())
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()

# %%
lambda_df = station_df.filter(regex=f"REFR\({lambda_val}\)_med|id", axis = 1)
#print(lambda_df.head())
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()

# %% [markdown]
# ## REFI((lambda_val))_F

# %%
lambda_df = station_df.filter(regex=f"REFI\({lambda_val}\)_[avg$|std$]|id", axis = 1)
#print(lambda_df.head())
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()

# %%
lambda_df = station_df.filter(regex=f"REFI\({lambda_val}\)_med|id", axis = 1)
#print(lambda_df.head())
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()

# %% [markdown]
# ## ASYM(lambda_val)-T

# %%
lambda_df = station_df.filter(regex=f"ASYM{lambda_val}-T_[avg$|std$]|id", axis = 1)
#print(lambda_df.head())
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()

# %%
lambda_df = station_df.filter(regex=f"ASYM{lambda_val}-T_med|id", axis = 1)
#print(lambda_df.head())
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()

# %% [markdown]
# ## ASYM(lambda_val)-C

# %%
lambda_df = station_df.filter(regex=f"ASYM{lambda_val}-C_[avg$|std$]|id", axis = 1)
#print(lambda_df.head())
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()

# %%
lambda_df = station_df.filter(regex=f"ASYM{lambda_val}-C_med|id", axis = 1)
#print(lambda_df.head())
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()

# %% [markdown]
# ## ASYM(lambda_val)-F

# %%
lambda_df = station_df.filter(regex=f"ASYM{lambda_val}-F_[avg$|std$]|id", axis = 1)
#print(lambda_df.head())
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()

# %%
lambda_df = station_df.filter(regex=f"ASYM{lambda_val}-F_med|id", axis = 1)
#print(lambda_df.head())
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()

# %% [markdown]
# ## 870-440AngstromParam,[AOTExt]-Total

# %%
lambda_df = station_df.filter(regex=f"870-440AngstromParam,\[AOTExt\]-Total_[avg$|std$]|id", axis = 1)
#print(lambda_df.head())
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()

# %%
lambda_df = station_df.filter(regex=f"870-440AngstromParam,\[AOTExt\]-Total_med|id", axis = 1)
#print(lambda_df.head())
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()

# %% [markdown]
# ## Inflection_Point

# %%
lambda_df = station_df.filter(regex=f"Inflection_Point\[um\]_[avg$|std$]|id", axis = 1)
#print(lambda_df.head())
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()

# %%
lambda_df = station_df.filter(regex=f"Inflection_Point\[um\]_med|id", axis = 1)
#print(lambda_df.head())
result_df = result_df.merge(lambda_df, on='id', how='inner')
result_df.head()

# %% [markdown]
# ## HE *

# %%
values = ["0,500000","0,065604","0,086077","0,112939","0,148184","0,194429","0,255105","0,334716",
          "0,439173","0,576227","0,756052","0,991996","1,301571","1,707757","2,240702",
          "2,939966","3,857452","5,061260","6,640745","8,713145","11,432287","15,000000"]

# %%
for value in values:
    lambda_df = station_df.filter(regex=f"{value}_[avg$|std$]|id", axis = 1)
    result_df = result_df.merge(lambda_df, on='id', how='inner')
    lambda_df = station_df.filter(regex=f"{value}_med|id", axis = 1)
    result_df = result_df.merge(lambda_df, on='id', how='inner')

# %%
result_df.delete(['id'], axis = 1)
# Out:
#      dd  mm  yyyy  nobs AOT_1020_avg AOT_1020_std AOT_1020_med  \
# 0    20   6  1998     2     0,378359  0,000850499     0,378359
# 1    22   4  1999     2     0,062176     0,008567     0,062176
# 2    29   4  1999     2    0,0861475    0,0040385    0,0861475
# 3     6   5  1999     2    0,0734765    0,0063095    0,0734765
# 4     7   5  1999     2     0,170561    0,0133005      0,17056
# ..   ..  ..   ...   ...          ...          ...          ...
# 201  28   1  2015     3    0,0357157   0,00793334     0,034604
# 202  29   1  2015     6    0,0405338   0,00353652    0,0382545
# 203  30   1  2015     3    0,0307837   0,00394559     0,033324
# 204  31   1  2015     2    0,0346435  0,000912501    0,0346435
# 205   2   2  2015     2     0,035006     0,007214     0,035006
#
#     AOTExt1020-T_avg AOTExt1020-T_std AOTExt1020-T_med AOTExt1020-C_avg  \
# 0            0,38135          0,00125          0,38135           0,3617
# 1             0,0628           0,0092           0,0628           0,0567
# 2            0,08705          0,00385          0,08705           0,0773
# 3            0,07575          0,00705          0,07575          0,06645
# 4            0,16985          0,01295          0,16985          0,14985
# ..               ...              ...              ...              ...
# 201        0,0406333       0,00613043           0,0421        0,0366667
# 202           0,0428       0,00353459          0,04305        0,0395667
# 203        0,0327333       0,00316895           0,0333           0,0293
# 204          0,03575          0,00185          0,03575           0,0323
# 205           0,0394           0,0039           0,0394          0,03525
#
#     AOTExt1020-C_std AOTExt1020-C_med AOTExt1020-F_avg AOTExt1020-F_std
# 0         0,00139999           0,3617          0,01965          0,00265
# 1             0,0076           0,0567           0,0061           0,0016
# 2             0,0033           0,0773           0,0098           0,0005
# 3            0,00495          0,06645           0,0093           0,0021
# 4            0,01355          0,14985             0,02           0,0006
# ..               ...              ...              ...              ...
# 201       0,00575751           0,0365       0,00396667       0,00118977
# 202       0,00351694          0,04015       0,00321667      0,000279384
# 203       0,00308221           0,0298       0,00343333         9,43E-05
# 204           0,0017           0,0323          0,00345          0,00015
# 205          0,00325          0,03525          0,00415          0,00065
#
# [206 rows x 15 columns]

# %%
result_df.to_csv(f"comeback_{lambda_val}_{filename}", index=False)
